# %%
import glob

# %%
glob.glob('/Users/isabelmetzger/PycharmProjects/ClinicalScorecard/data/train/*')
# Out:
# ['/Users/isabelmetzger/PycharmProjects/ClinicalScorecard/data/train/train_norm.txt',
#  '/Users/isabelmetzger/PycharmProjects/ClinicalScorecard/data/train/train_note',
#  '/Users/isabelmetzger/PycharmProjects/ClinicalScorecard/data/train/train_norm',
#  '/Users/isabelmetzger/PycharmProjects/ClinicalScorecard/data/train/train_file_list.txt']

# %%
import pandas as pd
list_of_files_df = pd.read_csv('/Users/isabelmetzger/PycharmProjects/ClinicalScorecard/data/train/train_file_list.txt', header=None)

# %%
def return_df_cuis(pathname):
    with open(file=pathname) as f:
        file_lines = f.readlines()
        return([f.strip('\n').split('||') for f in file_lines])

# print(list)
# for x in list_of_files_df[0]:
#     x
return_df_cuis('/Users/isabelmetzger/PycharmProjects/ClinicalScorecard/data/train/train_norm/638157550_SC.norm')
# Out:
# [['N000', 'C0017152', '52', '61'],
#  ['N001', 'C0002645', '462', '473'],
#  ['N002', 'C0079488', '520', '528'],
#  ['N003', 'C0055856', '604', '618'],
#  ['N005', 'C0074554', '833', '844'],
#  ['N006', 'C0055856', '849', '863'],
#  ['N007', 'C0074554', '898', '909'],
#  ['N008', 'C0055856', '914', '928'],
#  ['N009', 'C0020261', '966', '985'],
#  ['N011', 'C3207261', '1217', '1234'],
#  ['N012', 'C0074554', '1276', '1287'],
#  ['N013', 'C0055856', '1292', '1306'],
#  ['N014', 'C0074554', '1341', '1352'],
#  ['N015', 'C0055856', '1357', '1371'],
#  ['N020', 'C0937846', '1828', '1840'],
#  ['N022', 'C0086787', '2022', '2030'],
#  ['N024', 'C0065374', '2047', '2057'],
#  ['N025', 'C0004147', '2060', '2068'],
#  ['N026', 'C0017152', '2087', '2096'],
#  ['N027', 'C0017152', '2177', '2186'],
#  ['N028', 'C0028754', '2274', '2281'],
#  ['N029', 'C0020538', '2282', '2285'],
#  ['N030', 'C0020443', '2286', '2302'],
#  ['N031', 'C1956346', '2318', '2321'],
# ...
